# %%
#pseudo-code from Tim 
#Primary question: how to construct a set of wrenches to analyze sans force data?

from scipy.spatial import ConvexHull

def construct_wrench_space(forces, contact_points):
    """
    Constructs a wrench space by approximating the friction cone generated by 
    each contact point as a pyramid of distinct force vectors (assuming
    Coulomb friction).
    """


G = construct_wrench_space(forces, positions)
hull = ConvexHull(G)
metric = hull.volume()
